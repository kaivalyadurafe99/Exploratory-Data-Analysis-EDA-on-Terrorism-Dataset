# %% [markdown]
# **DATA SCIENCE INTERNSHIP AT LETSGROWMORE**

# %% [markdown]
# **LGMVIP FEB-2022**

# %% [markdown]
# **Author :- Kaivalya Durafe**

# %% [markdown]
# # Task-1 :-  Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# #### Importing all the libraries:

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Reading and Analyzing the Dataset:

# %%
df=pd.read_csv("globalterrorismdb.csv",encoding='latin1')
df.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,31,33,61,62,76,79,90,92,94,96,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0   197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1   197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2   197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3   197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4   197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 5   197001010002   1970       1     1  ...     -9.0       0.0    -9.0      NaN
# 6   197001020001   1970       1     2  ...      0.0       0.0     0.0      NaN
# 7   197001020002   1970       1     2  ...     -9.0       0.0    -9.0      NaN
# 8   197001020003   1970       1     2  ...      0.0       0.0     0.0      NaN
# 9   197001030001   1970       1     3  ...      0.0       0.0     0.0      NaN
# 10  197001050001   1970       1     1  ...      0.0       0.0     0.0      NaN
# 11  197001060001   1970       1     6  ...     -9.0       0.0    -9.0      NaN
# 12  197001080001   1970       1     8  ...     -9.0       1.0     1.0      NaN
# 13  197001090001   1970       1     9  ...     -9.0       0.0    -9.0      NaN
# 14  197001090002   1970       1     9  ...      0.0       0.0     0.0      NaN
# 15  197001100001   1970       1    10  ...      1.0       1.0     1.0      NaN
# 16  197001110001   1970       1    11  ...      1.0       1.0     1.0      NaN
# 17  197001120001   1970       1    12  ...     -9.0       0.0    -9.0      NaN
# 18  197001120002   1970       1    12  ...     -9.0       0.0    -9.0      NaN
# 19  197001130001   1970       1    13  ...     -9.0       0.0    -9.0      NaN
#
# [20 rows x 135 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %% [markdown]
# #### Renaming the Columns:

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

df.head(20)
# Out:
#     Year  Month  ...      Weapon                                             motive
# 0   1970      7  ...     Unknown                                                NaN
# 1   1970      0  ...     Unknown                                                NaN
# 2   1970      1  ...     Unknown                                                NaN
# 3   1970      1  ...  Explosives                                                NaN
# 4   1970      1  ...  Incendiary                                                NaN
# 5   1970      1  ...    Firearms     To protest the Cairo Illinois Police Deparment
# 6   1970      1  ...    Firearms                                                NaN
# 7   1970      1  ...  Explosives                                                NaN
# 8   1970      1  ...  Incendiary        To protest the War in Vietnam and the draft
# 9   1970      1  ...  Incendiary        To protest the War in Vietnam and the draft
# 10  1970      1  ...  Explosives                                                NaN
# 11  1970      1  ...  Incendiary                  Protest the draft and Vietnam War
# 12  1970      1  ...    Firearms                                                NaN
# 13  1970      1  ...  Incendiary                                                NaN
# 14  1970      1  ...  Incendiary  To protest United States owned businesses in P...
# 15  1970      1  ...  Explosives                                                NaN
# 16  1970      1  ...     Unknown                                                NaN
# 17  1970      1  ...  Explosives  Suspected motives were to protest the Vietnam ...
# 18  1970      1  ...  Explosives                                                NaN
# 19  1970      1  ...  Incendiary  Retaliation for the store owner who shot and k...
#
# [20 rows x 18 columns]

# %% [markdown]
# #### Calculating the Shape of the Dataset:

# %%
df.shape
# Out:
# (43732, 18)

# %% [markdown]
# #### Calculating the total Null or NA Values in the Dataset:

# %%
df.isnull().sum()
# Out:
# Year              0
# Month             0
# day               0
# Country           0
# State           168
# Region            0
# City              0
# latitude       2363
# longitude      2363
# Attacktype        0
# kill           5688
# Wound          7516
# target1         379
# summary       42532
# Group             0
# Targettype        0
# Weapon            1
# motive        42810
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 103820

# %% [markdown]
# #### Performing the operations on Missing Values:

# %%
df['Wound'] = df['Wound'].fillna(0)
df['kill'] = df['kill'].fillna(0)

# %%
df['Casualities'] = df['kill'] + df['Wound']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43732 entries, 0 to 43731
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         43732 non-null  int64
#  1   Month        43732 non-null  int64
#  2   day          43732 non-null  int64
#  3   Country      43732 non-null  object
#  4   State        43564 non-null  object
#  5   Region       43732 non-null  object
#  6   City         43732 non-null  object
#  7   latitude     41369 non-null  float64
#  8   longitude    41369 non-null  float64
#  9   Attacktype   43732 non-null  object
#  10  kill         43732 non-null  float64
#  11  Wound        43732 non-null  float64
#  12  target1      43353 non-null  object
#  13  summary      1200 non-null   object
#  14  Group        43732 non-null  object
#  15  Targettype   43732 non-null  object
#  16  Weapon       43731 non-null  object
#  17  motive       922 non-null    object
#  18  Casualities  43732 non-null  float64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 6.3+ MB

# %% [markdown]
# #### Describing the Dataset:

# %%
df.describe()
# Out:
#                Year         Month  ...         Wound   Casualities
# count  43732.000000  43732.000000  ...  43732.000000  43732.000000
# mean    1983.210281      6.307761  ...      1.397444      3.239024
# std        4.940538      3.360100  ...      9.418919     13.706084
# min     1970.000000      0.000000  ...      0.000000      0.000000
# 25%     1980.000000      3.000000  ...      0.000000      0.000000
# 50%     1984.000000      6.000000  ...      0.000000      0.000000
# 75%     1987.000000      9.000000  ...      0.000000      2.000000
# max     1991.000000     12.000000  ...    751.000000    760.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# #### Correlation and Heatmap:

# %%
df.corr()
# Out:
#                  Year     Month       day  ...      kill     Wound  Casualities
# Year         1.000000 -0.039196  0.012960  ...  0.053703  0.033023     0.054700
# Month       -0.039196  1.000000 -0.001106  ...  0.007906  0.014357     0.014578
# day          0.012960 -0.001106  1.000000  ... -0.004090 -0.002414    -0.004097
# latitude    -0.344080 -0.037137 -0.006231  ... -0.040075  0.020948    -0.008574
# longitude    0.001149 -0.008329 -0.004816  ... -0.002028  0.000732    -0.000663
# kill         0.053703  0.007906 -0.004090  ...  1.000000  0.210652     0.740744
# Wound        0.033023  0.014357 -0.002414  ...  0.210652  1.000000     0.812752
# Casualities  0.054700  0.014578 -0.004097  ...  0.740744  0.812752     1.000000
#
# [8 rows x 8 columns]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# #### Performing Some Data Visualization:

# %%
df['Year'].value_counts(dropna = False).sort_index()
# Out:
# 1970     651
# 1971     471
# 1972     568
# 1973     473
# 1974     581
# 1975     740
# 1976     923
# 1977    1319
# 1978    1526
# 1979    2662
# 1980    2662
# 1981    2586
# 1982    2544
# 1983    2870
# 1984    3495
# 1985    2915
# 1986    2860
# 1987    3183
# 1988    3721
# 1989    4324
# 1990    2657
# 1991       1
# Name: Year, dtype: int64

# %%
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years,
           palette = 'dark')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.barplot(df['Country'].value_counts()[:15].index,df['Country'].value_counts()[:15].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.subplots(figsize=(16,8))
df.groupby(['Region', 'Year']).count()['Casualities'].plot()
plt.xticks(rotation=90)
plt.ylabel("Casualities")
# Out:
# Text(0, 0.5, 'Casualities')

# %%
plt.subplots(figsize=(15,5))
sns.countplot('Region',data=df,palette='inferno',order=df['Region'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Regions')
plt.title('Number Of Attacks By Region')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
Weapon_data = df['Weapon'].value_counts()
Weapon_data
# Out:
# Explosives                                                                     19675
# Firearms                                                                       16293
# Unknown                                                                         3991
# Incendiary                                                                      3277
# Melee                                                                            371
# Chemical                                                                          56
# Sabotage Equipment                                                                29
# Other                                                                             12
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)       11
# Biological                                                                         8
# Fake Weapons                                                                       5
# Radiological                                                                       3
# Name: Weapon, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Weapon_data.index , y = Weapon_data.values)
plt.title('Most Used Weapon Type')
plt.xlabel('Weapon Type')
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color=['maroon'])
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
df['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='indigo')
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Name of attacktype",fontsize=20)
plt.show()

# %%
df[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['red'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.xticks(rotation=50)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %%
Target_data = df['Targettype'].value_counts().nlargest(n=15)
Target_data
# Out:
# Business                          7631
# Private Citizens & Property       7242
# Military                          6835
# Government (General)              5629
# Police                            4732
# Utilities                         2739
# Transportation                    2113
# Government (Diplomatic)           1554
# Journalists & Media               1020
# Educational Institution            917
# Airports & Aircraft                725
# Religious Figures/Institutions     641
# Terrorists/Non-State Militia       415
# Telecommunication                  330
# Unknown                            312
# Name: Targettype, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Target_data.index , y = Target_data.values,palette='pastel')
plt.title('Most Frequent Target Type')
plt.xlabel('Target Type')
plt.xticks(rotation=50)
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df=df[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                                               Group         Country    kill
# 0                                 Shining Path (SL)            Peru  9248.0
# 1  Farabundo Marti National Liberation Front (FMLN)     El Salvador  7380.0
# 2                 Nicaraguan Democratic Force (FDN)       Nicaragua  6630.0
# 3           Liberation Tigers of Tamil Eelam (LTTE)       Sri Lanka  3388.0
# 4                           New People's Army (NPA)     Philippines  2292.0
# 5     Mozambique National Resistance Movement (MNR)      Mozambique  1973.0
# 6     Revolutionary Armed Forces of Colombia (FARC)        Colombia  1937.0
# 7          Democratic Revolutionary Alliance (ARDE)       Nicaragua  1803.0
# 8                       Irish Republican Army (IRA)  United Kingdom  1587.0
# 9                                   Sikh Extremists           India  1396.0

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 37634

# %%
CountryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
CountryKill
# Out:
# Country  Colombia  El Salvador   India  ...  Philippines  Sri Lanka  United Kingdom
# kill       1937.0       7380.0  1396.0  ...       2292.0     3388.0          1587.0
#
# [1 rows x 9 columns]

# %% [markdown]
# **Conclusion Derived from Terrorism Dataset :**

# %% [markdown]
#   1) Regions with most attacks are Middle East & North Africa , South Asia and South America.
#
#   2) Most frequent terrorist groups involved in attacks are Taliban and Islamic State of Iraq and the Levant (ISIL).
#
#   3) Country with most attack - Iraq
#
#   4) Year with most attacks is 2014.
#
#   5) States with most attacks are Baghdad,Northern Ireland and Unknown state.

# %% [markdown]
# **Insights Derived from Terrorism Dataset :**

# %% [markdown]
# As here from the above analysis we can see that the most frequent way of attack is Bombing or Explosion.
#
# Now, if we see how we can can decrease it:
#
#   1] We can stop the supplies.
#
#   2] We can be on high alert in the areas where the explosions are most likely to happen.
#
#   3] CCTV cameras can be a great help for proper surveillance.
