# %% [markdown]
# **DATA SCIENCE INTERNSHIP AT LETSGROWMORE**

# %% [markdown]
# **LGMVIP FEB-2022**

# %% [markdown]
# **Author :- Kaivalya Durafe**

# %% [markdown]
# # Task-3 :-  Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# #### Importing all the libraries:

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Reading and Analyzing the Dataset:

# %%
df=pd.read_csv("globalterrorism.csv",encoding='latin1')
df.head(20)
# Out:
#          eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0   197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1   197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2   197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3   197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4   197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 5   197001010002   1970       1     1  ...     -9.0       0.0    -9.0      NaN
# 6   197001020001   1970       1     2  ...      0.0       0.0     0.0      NaN
# 7   197001020002   1970       1     2  ...     -9.0       0.0    -9.0      NaN
# 8   197001020003   1970       1     2  ...      0.0       0.0     0.0      NaN
# 9   197001030001   1970       1     3  ...      0.0       0.0     0.0      NaN
# 10  197001050001   1970       1     1  ...      0.0       0.0     0.0      NaN
# 11  197001060001   1970       1     6  ...     -9.0       0.0    -9.0      NaN
# 12  197001080001   1970       1     8  ...     -9.0       1.0     1.0      NaN
# 13  197001090001   1970       1     9  ...     -9.0       0.0    -9.0      NaN
# 14  197001090002   1970       1     9  ...      0.0       0.0     0.0      NaN
# 15  197001100001   1970       1    10  ...      1.0       1.0     1.0      NaN
# 16  197001110001   1970       1    11  ...      1.0       1.0     1.0      NaN
# 17  197001120001   1970       1    12  ...     -9.0       0.0    -9.0      NaN
# 18  197001120002   1970       1    12  ...     -9.0       0.0    -9.0      NaN
# 19  197001130001   1970       1    13  ...     -9.0       0.0    -9.0      NaN
#
# [20 rows x 135 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %% [markdown]
# #### Renaming the Columns:

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

df.head(20)
# Out:
#     Year  Month  day             Country        State  \
# 0   1970      7    2  Dominican Republic          NaN
# 1   1970      0    0              Mexico      Federal
# 2   1970      1    0         Philippines       Tarlac
# 3   1970      1    0              Greece       Attica
# 4   1970      1    0               Japan      Fukouka
# 5   1970      1    1       United States     Illinois
# 6   1970      1    2             Uruguay   Montevideo
# 7   1970      1    2       United States   California
# 8   1970      1    2       United States    Wisconsin
# 9   1970      1    3       United States    Wisconsin
# 10  1970      1    1       United States    Wisconsin
# 11  1970      1    6       United States     Colorado
# 12  1970      1    8               Italy        Lazio
# 13  1970      1    9       United States     Michigan
# 14  1970      1    9       United States  Puerto Rico
# 15  1970      1   10  East Germany (GDR)       Berlin
# 16  1970      1   11            Ethiopia      Unknown
# 17  1970      1   12       United States     New York
# 18  1970      1   12       United States  Puerto Rico
# 19  1970      1   13       United States   Washington
#
#                          Region           City   latitude   longitude  \
# 0   Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                 North America    Mexico city  19.371887  -99.086624
# 2                Southeast Asia        Unknown  15.478598  120.599741
# 3                Western Europe         Athens  37.997490   23.762728
# 4                     East Asia        Fukouka  33.580412  130.396361
# 5                 North America          Cairo  37.005105  -89.176269
# 6                 South America     Montevideo -34.891151  -56.187214
# 7                 North America        Oakland  37.791927 -122.225906
# 8                 North America        Madison  43.076592  -89.412488
# 9                 North America        Madison  43.072950  -89.386694
# 10                North America        Baraboo  43.468500  -89.744299
# 11                North America         Denver  39.758968 -104.876305
# 12               Western Europe           Rome  41.890961   12.490069
# 13                North America        Detroit  42.331685  -83.047924
# 14                North America    Rio Piedras  18.386932  -66.061127
# 15               Eastern Europe         Berlin  52.501530   13.401851
# 16           Sub-Saharan Africa        Unknown        NaN         NaN
# 17                North America  New York City  40.697132  -73.931351
# 18                North America     Rio Grande  18.379998  -65.830948
# 19                North America        Seattle  47.610786 -122.331306
#
#                         Attacktype  kill  Wound  \
# 0                    Assassination   1.0    0.0
# 1      Hostage Taking (Kidnapping)   0.0    0.0
# 2                    Assassination   1.0    0.0
# 3                Bombing/Explosion   NaN    NaN
# 4   Facility/Infrastructure Attack   NaN    NaN
# 5                    Armed Assault   0.0    0.0
# 6                    Assassination   0.0    0.0
# 7                Bombing/Explosion   0.0    0.0
# 8   Facility/Infrastructure Attack   0.0    0.0
# 9   Facility/Infrastructure Attack   0.0    0.0
# 10               Bombing/Explosion   0.0    0.0
# 11  Facility/Infrastructure Attack   0.0    0.0
# 12                       Hijacking   0.0    0.0
# 13  Facility/Infrastructure Attack   0.0    0.0
# 14  Facility/Infrastructure Attack   0.0    0.0
# 15               Bombing/Explosion   NaN    NaN
# 16                         Unknown   1.0    0.0
# 17               Bombing/Explosion   0.0    0.0
# 18               Bombing/Explosion   0.0    0.0
# 19  Facility/Infrastructure Attack   0.0    0.0
#
#                                               target1  \
# 0                                        Julio Guzman
# 1                             Nadine Chaval, daughter
# 2                                            Employee
# 3                                        U.S. Embassy
# 4                                      U.S. Consulate
# 5                           Cairo Police Headquarters
# 6   Juan Maria de Lucah/Chief of Directorate of in...
# 7                                     Edes Substation
# 8   R.O.T.C. offices at University of Wisconsin, M...
# 9   Selective Service Headquarters in Madison Wisc...
# 10                            Badger Army ammo depot.
# 11           Army Recruiting Station, Denver Colorado
# 12                              Flight 802 Boeing 707
# 13    Packard Properties building of Detroit Michigan
# 14                                      Baker's Store
# 15                 Jurists Ball (Palais au Frankturm)
# 16                                            Soldier
# 17                          James Madison High School
# 18  General Electric factory in Rio Grande Puerto ...
# 19       Fuson's Department Store, Seattle Washington
#
#                                               summary  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1/1/1970: Unknown African American assailants ...
# 6                                                 NaN
# 7   1/2/1970: Unknown perpetrators detonated explo...
# 8   1/2/1970: Karl Armstrong, a member of the New ...
# 9   1/3/1970: Karl Armstrong, a member of the New ...
# 10                                                NaN
# 11  1/6/1970: Unknown perpetrators threw a Molotov...
# 12                                                NaN
# 13  1/9/1970: Unknown perpetrators set off a fireb...
# 14  1/9/1970:  The Armed Commandos of Liberation c...
# 15                                                NaN
# 16                                                NaN
# 17  1/12/1970: Unknown perpetrators threw a pipe b...
# 18  1/12/1970: Unknown perpetrators detonated a bo...
# 19  1/13/1970: Unknown perpetrators firebombed Fus...
#
#                                  Group                   Targettype  \
# 0                               MANO-D  Private Citizens & Property
# 1   23rd of September Communist League      Government (Diplomatic)
# 2                              Unknown          Journalists & Media
# 3                              Unknown      Government (Diplomatic)
# 4                              Unknown      Government (Diplomatic)
# 5                   Black Nationalists                       Police
# 6                  Tupamaros (Uruguay)                       Police
# 7                              Unknown                    Utilities
# 8                      New Year's Gang                     Military
# 9                      New Year's Gang         Government (General)
# 10     Weather Underground, Weathermen                     Military
# 11                 Left-Wing Militants                     Military
# 12                             Unknown          Airports & Aircraft
# 13                 Left-Wing Militants         Government (General)
# 14       Armed Commandos of Liberation                     Business
# 15                           Commune 1         Government (General)
# 16           Eritrean Liberation Front                     Military
# 17                  Black Nationalists      Educational Institution
# 18                            Strikers                     Business
# 19                  Black Nationalists                     Business
#
#         Weapon                                             motive
# 0      Unknown                                                NaN
# 1      Unknown                                                NaN
# 2      Unknown                                                NaN
# 3   Explosives                                                NaN
# 4   Incendiary                                                NaN
# 5     Firearms     To protest the Cairo Illinois Police Deparment
# 6     Firearms                                                NaN
# 7   Explosives                                                NaN
# 8   Incendiary        To protest the War in Vietnam and the draft
# 9   Incendiary        To protest the War in Vietnam and the draft
# 10  Explosives                                                NaN
# 11  Incendiary                  Protest the draft and Vietnam War
# 12    Firearms                                                NaN
# 13  Incendiary                                                NaN
# 14  Incendiary  To protest United States owned businesses in P...
# 15  Explosives                                                NaN
# 16     Unknown                                                NaN
# 17  Explosives  Suspected motives were to protest the Vietnam ...
# 18  Explosives                                                NaN
# 19  Incendiary  Retaliation for the store owner who shot and k...

# %% [markdown]
# #### Calculating the Shape of the Dataset:

# %%
df.shape
# Out:
# (27672, 135)

# %% [markdown]
# #### Calculating the total Null or NA Values in the Dataset:

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2315899

# %% [markdown]
# #### Performing the operations on Missing Values:

# %%
df['Wound'] = df['Wound'].fillna(0)
df['kill'] = df['kill'].fillna(0)

# %%
df['Casualities'] = df['kill'] + df['Wound']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27672 entries, 0 to 27671
# Columns: 136 entries, eventid to Casualities
# dtypes: float64(72), int64(7), object(57)
# memory usage: 28.7+ MB

# %% [markdown]
# #### Describing the Dataset:

# %%
df.describe()
# Out:
#             eventid          Year  ...       INT_ANY   Casualities
# count  2.767200e+04  27672.000000  ...  27671.000000  27672.000000
# mean   1.980418e+11   1980.354257  ...     -2.423331      3.024574
# std    3.922739e+08      3.924702  ...      4.374893     14.452022
# min    1.970000e+11   1970.000000  ...     -9.000000      0.000000
# 25%    1.978103e+11   1978.000000  ...     -9.000000      0.000000
# 50%    1.981071e+11   1981.000000  ...      0.000000      0.000000
# 75%    1.984012e+11   1984.000000  ...      1.000000      1.000000
# max    1.986033e+11   1987.000000  ...      1.000000    760.000000
#
# [8 rows x 79 columns]

# %% [markdown]
# #### Correlation ans Heatmap:

# %%
df.corr()
# Out:
#               eventid      Year     Month  ...  INT_MISC   INT_ANY  Casualities
# eventid      1.000000  0.999931 -0.046981  ... -0.187472 -0.040758     0.076750
# Year         0.999931  1.000000 -0.055762  ... -0.187623 -0.040714     0.076539
# Month       -0.046981 -0.055762  1.000000  ...  0.027234 -0.009799     0.019217
# day         -0.015670 -0.015929  0.012848  ...  0.023528  0.003266    -0.001400
# extended    -0.053917 -0.053878  0.005912  ...  0.034634  0.030679    -0.010992
# ...               ...       ...       ...  ...       ...       ...          ...
# INT_LOG      0.048472  0.048514 -0.013513  ...  0.078512  0.830773     0.027033
# INT_IDEO     0.046552  0.046590 -0.012626  ...  0.113323  0.834348     0.027641
# INT_MISC    -0.187472 -0.187623  0.027234  ...  1.000000  0.320812    -0.018585
# INT_ANY     -0.040758 -0.040714 -0.009799  ...  0.320812  1.000000     0.006137
# Casualities  0.076750  0.076539  0.019217  ... -0.018585  0.006137     1.000000
#
# [79 rows x 79 columns]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# #### Performing Some Data Visualization:

# %%
df['Year'].value_counts(dropna = False).sort_index()
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %%
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years,
           palette = 'dark')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.barplot(df['Country'].value_counts()[:15].index,df['Country'].value_counts()[:15].values)
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.subplots(figsize=(16,8))
df.groupby(['Region', 'Year']).count()['Casualities'].plot()
plt.xticks(rotation=90)
plt.ylabel("Casualities")
# Out:
# Text(0, 0.5, 'Casualities')

# %%
plt.subplots(figsize=(15,5))
sns.countplot('Region',data=df,palette='inferno',order=df['Region'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Regions')
plt.title('Number Of Attacks By Region')
plt.show()

# %%
Weapon_data = df['Weapon'].value_counts()
Weapon_data
# Out:
# Explosives                                                                     12413
# Firearms                                                                        9619
# Unknown                                                                         3083
# Incendiary                                                                      2299
# Melee                                                                            170
# Chemical                                                                          42
# Sabotage Equipment                                                                17
# Other                                                                              9
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)        6
# Biological                                                                         6
# Fake Weapons                                                                       4
# Radiological                                                                       3
# Name: Weapon, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Weapon_data.index , y = Weapon_data.values)
plt.title('Most Used Weapon Type')
plt.xlabel('Weapon Type')
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color=['maroon'])
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
df['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='indigo')
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Name of attacktype",fontsize=20)
plt.show()

# %%
df[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['red'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.xticks(rotation=50)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %%
Target_data = df['Targettype'].value_counts().nlargest(n=15)
Target_data
# Out:
# Business                          5271
# Military                          4423
# Private Citizens & Property       4408
# Government (General)              3174
# Police                            2769
# Utilities                         1536
# Government (Diplomatic)           1282
# Transportation                    1201
# Journalists & Media                709
# Educational Institution            642
# Airports & Aircraft                606
# Religious Figures/Institutions     365
# Terrorists/Non-State Militia       279
# Unknown                            273
# Telecommunication                  231
# Name: Targettype, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Target_data.index , y = Target_data.values,palette='pastel')
plt.title('Most Frequent Target Type')
plt.xlabel('Target Type')
plt.xticks(rotation=50)
plt.ylabel('Attacks count')
plt.xticks(rotation = 90)
plt.show()

# %%
df=df[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                                               Group         Country    kill
# 0                 Nicaraguan Democratic Force (FDN)       Nicaragua  6075.0
# 1  Farabundo Marti National Liberation Front (FMLN)     El Salvador  6038.0
# 2                                 Shining Path (SL)            Peru  5205.0
# 3          Democratic Revolutionary Alliance (ARDE)       Nicaragua  1803.0
# 4                       Irish Republican Army (IRA)  United Kingdom  1325.0
# 5     Revolutionary Armed Forces of Colombia (FARC)        Colombia  1194.0
# 6                       M-19 (Movement of April 19)        Colombia  1176.0
# 7                                            Tamils       Sri Lanka   793.0
# 8                           New People's Army (NPA)     Philippines   735.0
# 9                  Guerrilla Army of the Poor (EGP)       Guatemala   549.0

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 24893

# %%
CountryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
CountryKill
# Out:
# Country  Colombia  El Salvador  ...  Sri Lanka  United Kingdom
# kill       2370.0       6038.0  ...      793.0          1325.0
#
# [1 rows x 8 columns]

# %% [markdown]
# **Conclusion Derived from Terrorism Dataset :**

# %% [markdown]
#   1) Regions with most attacks are Middle East & North Africa , South Asia and South America.
#
#   2) Most frequent terrorist groups involved in attacks are Taliban and Islamic State of Iraq and the Levant (ISIL).
#
#   3) Country with most attack - Iraq
#
#   4) Year with most attacks is 2014.
#
#   5) States with most attacks are Baghdad,Northern Ireland and Unknown state.

# %% [markdown]
# **Insights Derived from Terrorism Dataset :**

# %% [markdown]
# As here from the above analysis we can see that the most frequent way of attack is Bombing or Explosion.
#
# Now, if we see how we can can decrease it:
#
#   1] We can stop the supplies.
#
#   2] We can be on high alert in the areas where the explosions are most likely to happen.
#
#   3] CCTV cameras can be a great help for proper surveillance.
